# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = x_axis

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x25c479eb7b8>,
#   <matplotlib.axis.XTick at 0x25c479eb128>,
#   <matplotlib.axis.XTick at 0x25c47782cf8>,
#   <matplotlib.axis.XTick at 0x25c47a9e470>,
#   <matplotlib.axis.XTick at 0x25c47a9e908>,
#   <matplotlib.axis.XTick at 0x25c47a9edd8>,
#   <matplotlib.axis.XTick at 0x25c47aac2e8>,
#   <matplotlib.axis.XTick at 0x25c47aac860>,
#   <matplotlib.axis.XTick at 0x25c47aacdd8>,
#   <matplotlib.axis.XTick at 0x25c47aac940>,
#   <matplotlib.axis.XTick at 0x25c47a9e9b0>,
#   <matplotlib.axis.XTick at 0x25c47ab26a0>,
#   <matplotlib.axis.XTick at 0x25c47ab2c18>,
#   <matplotlib.axis.XTick at 0x25c47aba1d0>,
#   <matplotlib.axis.XTick at 0x25c47aba748>,
#   <matplotlib.axis.XTick at 0x25c47abacc0>,
#   <matplotlib.axis.XTick at 0x25c47abf278>,
#   <matplotlib.axis.XTick at 0x25c47abf7f0>,
#   <matplotlib.axis.XTick at 0x25c47abfd68>,
#   <matplotlib.axis.XTick at 0x25c47abac18>,
#   <matplotlib.axis.XTick at 0x25c47ab25f8>,
#   <matplotlib.axis.XTick at 0x25c47ac82b0>,
#   <matplotlib.axis.XTick at 0x25c47ac8828>,
#   <matplotlib.axis.XTick at 0x25c47ac8da0>,
#   <matplotlib.axis.XTick at 0x25c47ace358>,
#   <matplotlib.axis.XTick at 0x25c47ace8d0>,
#   <matplotlib.axis.XTick at 0x25c47acee48>,
#   <matplotlib.axis.XTick at 0x25c47ad5400>,
#   <matplotlib.axis.XTick at 0x25c47acef28>,
#   <matplotlib.axis.XTick at 0x25c47ac8208>,
#   <matplotlib.axis.XTick at 0x25c47ad5748>,
#   <matplotlib.axis.XTick at 0x25c47ad5c50>,
#   <matplotlib.axis.XTick at 0x25c47add208>,
#   <matplotlib.axis.XTick at 0x25c47add780>,
#   <matplotlib.axis.XTick at 0x25c47addcf8>,
#   <matplotlib.axis.XTick at 0x25c47ae42b0>,
#   <matplotlib.axis.XTick at 0x25c47ae4828>,
#   <matplotlib.axis.XTick at 0x25c47ae4da0>,
#   <matplotlib.axis.XTick at 0x25c47ae4908>,
#   <matplotlib.axis.XTick at 0x25c47ad5d30>,
#   <matplotlib.axis.XTick at 0x25c47aea240>,
#   <matplotlib.axis.XTick at 0x25c47aea780>,
#   <matplotlib.axis.XTick at 0x25c47aeacf8>,
#   <matplotlib.axis.XTick at 0x25c47af12b0>,
#   <matplotlib.axis.XTick at 0x25c47af1828>,
#   <matplotlib.axis.XTick at 0x25c47af1da0>,
#   <matplotlib.axis.XTick at 0x25c47af8358>,
#   <matplotlib.axis.XTick at 0x25c47af16a0>,
#   <matplotlib.axis.XTick at 0x25c47aea6d8>,
#   <matplotlib.axis.XTick at 0x25c47af86a0>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(271.27777777777777, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("avg_state_rain.png")
plt.show()
